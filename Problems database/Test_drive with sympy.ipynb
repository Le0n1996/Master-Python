# %%
import sympy

# %%
sympy.preview(r'$$\text{solve:} \frac{6}{a^{2}}$$ \\ $$\text{newline}$$', viewer='file', filename='HA1.png')

# %%
preamble = "\\documentclass[10pt]{article}\n" \
            "\\usepackage{amsmath,amsfonts}" \
            "\\usepackage[russian]{babel}" \
            "\\begin{document}"

# %%
sympy.preview(r'$$\frac{1}{2}$$', output='png', preamble = preamble)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sympy\printing\preview.py in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, **latex_settings)
#     253                 check_output(cmd, cwd=workdir, stderr=STDOUT,
# --> 254                              creationflags=creation_flag)
#     255             except CalledProcessError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#
# ~\AppData\Local\Continuum\anaconda3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     486             raise CalledProcessError(retcode, process.args,
# ...

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- ----------
# absl-py                            0.9.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.7
# anaconda-project                   0.8.3
# asn1crypto                         0.24.0
# astor                              0.8.1
# astroid                            2.2.5
# astropy                            3.2.1
# atomicwrites                       1.3.0
# attrs                              19.1.0
# Babel                              2.7.0
# backcall                           0.1.0
# backports.functools-lru-cache      1.5
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.7.1
# bitarray                           0.9.3
# bkcharts                           0.2
# ...

# %%
pip install --upgrade --user gimp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Could not find a version that satisfies the requirement gimp (from versions: none)
# ERROR: No matching distribution found for gimp
